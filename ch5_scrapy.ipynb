# %% [markdown]
# <a href="https://colab.research.google.com/github/lblogan14/web_scraping_with_python/blob/master/ch5_scrapy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive') #add drive content to the notebook
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
'''Locate the directory which has the dataset'''
# %cd /content/drive/My\ \Drive/Colab\ \Notebooks/Web_Scraping_with_Python
# Out:
# /content/drive/My Drive/Colab Notebooks/Web_Scraping_with_Python

# %% [markdown]
# # New Section

# %% [markdown]
# #Installing Scrapy

# %%
# !pip3 install scrapy
# Out:
# ...
#      |████████████████████████████████| 235kB 4.9MB/s
# ...
#      |████████████████████████████████| 3.1MB 47.3MB/s
# ...
#      |████████████████████████████████| 61kB 22.8MB/s
# ...
#      |████████████████████████████████| 174kB 46.2MB/s
# ...
#      |████████████████████████████████| 61kB 23.8MB/s
# ...
#      |████████████████████████████████| 2.3MB 39.7MB/s
# ...
#      |████████████████████████████████| 102kB 28.3MB/s
# ...
#   Created wheel for Twisted: filename=Twisted-19.2.1-cp36-cp36m-linux_x86_64.whl size=3047355 sha256=b4fd7a947710133f06dcd8d9cc7d43f0706457ca6931f75aabb275f1cbae040a
#   Stored in directory: /root/.cache/pip/wheels/19/4c/a1/0bef832134076abab3461815e92cf41f2518dffe1a5337203b
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-cp36-none-any.whl size=11517 sha256=5e6fa161e767019530d9e7bbba2c599864dd5e32a66cdf557349bfded7b69111
#   Stored in directory: /root/.cache/pip/wheels/88/99/96/cfef6665f9cb1522ee6757ae5955feedf2fe25f1737f91fa7f
# Successfully built Twisted PyDispatcher
# ...

# %% [markdown]
# ##Initializing a New Spider
# A *spider* is a Scrapy project that is designed to crawl webs. After the Scrapy framework is installed, a small amount of setup needs to be done for each spider. \\
# Here, a "spider" is a Scrapy project and a "crawler" is any generic program that crawls the web using Scrapy or not.

# %% [markdown]
# The following command is used to create a new spider

# %%
# !scrapy startproject wikiSpider
# Out:
# New Scrapy project 'wikiSpider', using template directory '/usr/local/lib/python3.6/dist-packages/scrapy/templates/project', created in:
#     /content/drive/My Drive/Colab Notebooks/Web_Scraping_with_Python/wikiSpider
#
# You can start your first spider with:
#     cd wikiSpider
#     scrapy genspider example example.com

# %% [markdown]
# This creates a new subdirectory in the directory the  project was created in, with the title *wikispider*, which contains the following file structure:
# ![](https://github.com/lblogan14/web_scraping_with_python/blob/master/img/ch5/scrapy_project_file.JPG?raw=true)

# %% [markdown]
# #Writing a Simple Scraper
# The crawler is added inside the *spiders* directory at *wikiSpider/wikiSpider/spiders/article.py*. Add the following code in the new created *article.py* file

# %%
import scrapy

class ArticleSpider(scrapy.Spider):
  name = 'article'
  
  def start_requests(self):
    urls = [
        'http://en.wikipedia.org/wiki/Python_'
        '%28programming_language%29',
        'https://en.wikipedia.org/wiki/Functional_programming',
        'https://en.wikipedia.org/wiki/Monty_Python'
    ]
    return [scrapy.Request(url=url, callback=self.parse) for url in urls]
  
  def parse(self, response):
    url = response.url
    title = response.css('h1::text').extract_first()
    print('URL is: {}'.format(url))
    print('Title is: {}'.format(title))

# %% [markdown]
# For large sites with many types of content, it is a good idea to have separate Scrapy items for each type (blog posts, press releases, articles, etc), each with different fields, but all running under the same Scrapy project. The name of each spider must be unique
# within the project.

# %% [markdown]
# `start_request` is a Scrapy-defined entry point to the program used to generate `Request` objects that Scrapy uses to crawl the website. \\
# `parse` is a callback function defined by the user and is passed to the `Request` object with `callback=self.parse`.

# %% [markdown]
# Use the following command to run the `article` spider

# %%
# %cd /content/drive/My\ \Drive/Colab\ \Notebooks/Web_Scraping_with_Python/wikiSpider/wikiSpider/spiders
# Out:
# /content/drive/My Drive/Colab Notebooks/Web_Scraping_with_Python/wikiSpider/wikiSpider/spiders

# %%
# !scrapy runspider article.py
# Out:
# 2019-08-02 14:28:16 [scrapy.utils.log] INFO: Scrapy 1.7.3 started (bot: wikiSpider)
# 2019-08-02 14:28:16 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.2.1, Python 3.6.8 (default, Jan 14 2019, 11:02:34) - [GCC 8.0.1 20180414 (experimental) [trunk revision 259383]], pyOpenSSL 19.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.7, Platform Linux-4.14.79+-x86_64-with-Ubuntu-18.04-bionic
# 2019-08-02 14:28:16 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'wikiSpider', 'NEWSPIDER_MODULE': 'wikiSpider.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_LOADER_WARN_ONLY': True, 'SPIDER_MODULES': ['wikiSpider.spiders']}
# 2019-08-02 14:28:16 [scrapy.extensions.telnet] INFO: Telnet Password: 7e4096704002e3b6
# 2019-08-02 14:28:16 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
# ...

# %% [markdown]
# The scraper goes to the three pages listed as the `start_urls`, gathers information, and then terminates.

# %% [markdown]
# #Spidering with Rules
# To obtain useful information, need to use the `CrawlSpider` class provided by Scrapy. \\
# Add the following code in the new created *new_articles.py*:

# %%
from scrapy.linkextractors import LinkExtractor
from scrapy.spiders import CrawlSpider, Rule

class ArticleSpider(CrawlSpider):
  name = 'articles'
  allowed_domains = ['wikipedia.org']
  allowed_urls = ['https://en.wikipedia.org/wiki/Benevolent_dictator_for_life']
  rules = [Rule(LinkExtractor(allow=r'.*'), callback=self.parse_items, follow=True)]
  
  def parse_items(self, response):
    url = response.url
    title = response.css('h1::text').extract_first()
    text = response.xpath('//div[@id="mu-content-text"]//text()').extract()
    lastUpdated = response.css('li#footer-info-lastmod::text').extract_first()
    lastUpdated = lastUpdated.replace('This page was last edited on ', '')
    print('URL is: {}'.format(url))
    print('Title is: {}'.format(title))
    print('Text is: {}'.format(text))
    print('Last updated: {}'.format(lastUpdated))

# %% [markdown]
# This new `ArticleSpider` provides a list of `start_urls` and `allowed_domains` to tell the spider where to start crawling from and whether it should follow or ignore a link based on the domain. \\
# A list of `rules` provides further instructions on which links to follow or ignore. \\
# The text content of each page is extracted using an XPath selector, which is often used when retrieving text content including text in child tags

# %% [markdown]
# Use the following command to run the `articles.py`:
# Note that this will run forever... make sure to terminate manually!

# %%
# !scrapy runspider new_articles.py
# Out:
# 2019-08-02 14:29:30 [scrapy.utils.log] INFO: Scrapy 1.7.3 started (bot: wikiSpider)
# 2019-08-02 14:29:30 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.2.1, Python 3.6.8 (default, Jan 14 2019, 11:02:34) - [GCC 8.0.1 20180414 (experimental) [trunk revision 259383]], pyOpenSSL 19.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.7, Platform Linux-4.14.79+-x86_64-with-Ubuntu-18.04-bionic
# 2019-08-02 14:29:30 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'wikiSpider', 'NEWSPIDER_MODULE': 'wikiSpider.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_LOADER_WARN_ONLY': True, 'SPIDER_MODULES': ['wikiSpider.spiders']}
# 2019-08-02 14:29:30 [scrapy.extensions.telnet] INFO: Telnet Password: d53f5319631eb904
# 2019-08-02 14:29:30 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
# ...

# %% [markdown]
# This spider traverses *wikipedia.org*, following all links under the domain *wikipedia.org*, printing titles of pages, and ignoring all external (offsite) links.

# %%
rules = [Rule(LinkExtractor(allow=r'.*'), callback='parse_items',follow=True)]

# %% [markdown]
# This provides a list of Scrapy `Rule` object that defines the rules that all links found are filtered through. When multiple rules are in place, each link is checked against the rules in order.
#
# A `Rule` has six arguments:
# * `link_extractor`: Mandatory argument, a `LinkExtractor` object
# * `callback`: used to parse the content on the page
# * `cb_kwargs`: a dictionary of arugments which is formatted as `{arg_name1: arg_value1, arg_name2: arg_value2}`. Used to reuse the same parsing functions for slightly different tasks
# * `follow`: whether to include the found links at the page in a future crawl. Default is `True`
#
#
# A `LinkExtractor` is a simple class designed solely to recognize and return links in a page of HTML content based on the rules provided to it. It can be used to accept or deny a link based on CSS and XPath selectors, tags, domains, and more. The most common arguments are:
# * `allow`: allow all links that match the provided regular expression
# * `deny`: deny all links that match the provided regular expression

# %% [markdown]
# Using multiple separate `Rule` and `LinkExtractor` classes in a single parsing function to create a spider that crawls Wikipedia in order to identify all article pages and flag nonarticle pages. This code is saved as `moreRules_articles.py`:

# %%
from scrapy.linkextractors import LinkExtractor
from scrapy.spiders import CrawlSpider, Rule

class ArticleSpider(CrawlSpider):
  name = 'articles'
  allowed_domains = ['wikipedia.org']
  start_urls = ['https://en.wikipedia.org/wiki/Benevolent_dictator_for_life']
  rules = [
      Rule(LinkExtractor(allow='^(/wiki/)((?!:).)*$'),
           callback='parse_items',
           follow=True,
           cb_kwargs={'is_article': True}),
      Rule(LinkExtractor(allow='.*'),
           callback='parse_items',
           cb_kwargs={'is_article': False})
  ]
  
  def parse_items(self, response, is_article):
    print(response.url)
    title = response.css('h1::text').extract_first()
    if is_article:
      url = response.url
      text = response.xpath('//div[@id="mu-content-text"]//text()').extract()
      lastUpdated = response.css('li#footer-info-lastmod::text').extract_first()
      lastUpdated = lastUpdated.replace('This page was last edited on ', '')
      print('URL is: {}'.format(url))
      print('Title is: {} '.format(title))
      print('Text is: {}'.format(text))
    else:
      print('This is not an article: {}'.format(title))

# %%
# !scrapy runspider moreRules_article.py

# %% [markdown]
# #Creating Items
# Scrapy provides useful tools to keep collected items orgainzed and stored in custom objects with well-defined fields. \\
# Inside the *items.py* file which has been initialized, create a `Article` object: \\
# The default *items.py* looks like: \\
# ![](https://github.com/lblogan14/web_scraping_with_python/blob/master/img/ch5/item_py.JPG?raw=true)
#
# Replace that with the following:

# %%
class Article(scrapy.Item):
  url = scrapy.Field()
  title = scrapy.Field()
  text = scrapy.Field()
  lastUpdated = scrapy.Field()

# %% [markdown]
# There are three fields that will be collected from each page: a title, URL, and the date the page was last edited. For multiple page types, each separate type should be defined their own class in *item.py*.

# %% [markdown]
# To create the new `Article` item, a new class `articleItems.py` is created:

# %%
from scrapy.linkextractors import LinkExtractor
from scrapy.spiders import CrawlSpider, Rule
from wikiSpider.items import Article

class ArticleSpider(CrawlSpider):
  name = 'articleItems'
  allowed_domains = ['wikipedia.org']
  start_urls = ['https://en.wikipedia.org/wiki/Benevolent_dictator_for_life']
  rules = [
        Rule(LinkExtractor(allow='(/wiki/)((?!:).)*$'), callback='parse_items', follow=True),
  ]
  
  def parse_items(self, response):
    article = Article()
    article['url'] = response.url
    article['title'] = response.css('h1::text').extract_first()
    article['text'] = response.xpath('//div[@id="mu-content-text"]//text()').extract()
    lastUpdated = response.css('li#footer-info-lastmod::text').extract_first()
    article['lastUpdated'] = lastUpdated.replace('This page was last updated on ','')
    return article

# %%
# !scrapy runspider articleItems.py
# Out:
# 2019-08-02 15:16:59 [scrapy.utils.log] INFO: Scrapy 1.7.3 started (bot: wikiSpider)
# 2019-08-02 15:16:59 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.2.1, Python 3.6.8 (default, Jan 14 2019, 11:02:34) - [GCC 8.0.1 20180414 (experimental) [trunk revision 259383]], pyOpenSSL 19.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.7, Platform Linux-4.14.79+-x86_64-with-Ubuntu-18.04-bionic
# 2019-08-02 15:16:59 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'wikiSpider', 'NEWSPIDER_MODULE': 'wikiSpider.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_LOADER_WARN_ONLY': True, 'SPIDER_MODULES': ['wikiSpider.spiders']}
# 2019-08-02 15:16:59 [scrapy.extensions.telnet] INFO: Telnet Password: e1ed737d5e652f87
# 2019-08-02 15:16:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
# ...

# %% [markdown]
# Using Scrapy `Items` is not just for promoting good code organization or laying things
# out in a readable way. Items provide many tools for outputting and processing data.

# %% [markdown]
# #Outputting Items
# Scrapy uses the `Item` objects to determine which pieces of information it should save
# from the pages it visits. This information can be saved by Scrapy in different filetypes:
#
#
#
#
# ```
#  scrapy runspider articleItems.py -o articles.csv -t csv
#  scrapy runspider articleItems.py -o articles.json -t json
#  scrapy runspider articleItems.py -o articles.xml -t xml
# ```
#
# This runs the scraper `articleItems` and writes the output in the specified formata to the provided file.
#
# The `text` variable is a list of strings rather than a single string. Each string in this list represents text inside a single HTML element, whereas the content inside `<div id="mw-content-text">` is composed of many child elements.
#
# In the CSV format, it converts lists to strings and escapes all commas so that alist of text displays in a single CSV cell. \\
# In XML, each element of this list is preserved inside child value tags. \\
# In JSON, lists are preserved as lists.

# %% [markdown]
# #The Item Pipeline
# Using Scrapy's item pipeline can improve the speed of thee web scraper even further by performing all data processing while waiting for requests to be returned, rather than waiting for data to be processed before making another request.

# %% [markdown]
# To create an item pipeline, use the *settings.py* file. Find the following lines in this file:
#
#
# ```
# # Configure item pipelines
# # See https://docs.scrapy.org/en/latest/topics/item-pipeline.html
# #ITEM_PIPELINES = {
# #    'wikiSpider.pipelines.WikispiderPipeline': 300,
# #}
# ```
#
#
#
# Uncomment the last three lines and replace with the following:

# %%
ITEM_PIPELINES = {
    'wikiSpider.pipelines.WikispiderPipeline':300
}

# %% [markdown]
# This provides a Python class, `wikiSpider.pipelines.WikispiderPipeline`, that will
# be used to process the data, as well as an integer that represents the order in which to
# run the pipeline if there are multiple processing classes.

# %% [markdown]
# Next, add the pipeline class and rewrite the original spider so that the spider collects data and the pipeline does the heavy lifting of the data processing. \\
# The goal of `parse_items` is to extract the raw data, doing as little processing as possible, so that it can be passed to the pipeline. The following code is added in the *articlePipelines.py*:

# %%
from scrapy.linkextractors import LinkExtractor
from scrapy.spiders import CrawlSpider, Rule
from wikiSpider.items import Article

class ArticleSpider(CrawlSpider):
  name = 'articlePipelines'
  allowed_domains = ['wikipedia.org']
  start_urls = ['https://en.wikipedia.org/wiki/Benevolent_dictator_for_life']
  rules = [
    Rule(LinkExtractor(allow='(/wiki/)((?!:).)*$'), callback='parse_items', follow=True),
  ]

  def parse_items(self, response):
    article = Article()
    article['url'] = response.url
    article['title'] = response.css('h1::text').extract_first()
    article['text'] = response.xpath('//div[@id="mw-content-text"]//text()').extract()
    article['lastUpdated'] = response.css('li#footer-info-lastmod::text').extract_first()
    return article

# %% [markdown]
# Next, update the *pipelines.py* with the following code:

# %%
from datatime import datetime
from wikiSpider.items import Article
from string import whitespace

class WikispiderPipeline(object):
  
  def process_item(self, article, spider):
    dataStr = article['lastUpdated']
    article['lastUpdated'] = article['lastUpdated'].replace('This page was last edited on', '')
    article['lastUpdated'] = article['lastUpdated'].strip()
    article['lastUpdated'] = datetime.strptime(article['lastUpdated'], '%d %B %Y, at %H:%M.')
    article['text'] = [line for line in article['text'] if line not in whitespace]
    article['text'] = ''.join(article['text'])
    return article

# %% [markdown]
# The method `process_item` takes in an `Article` object, parses the `lastUpdated` string into a Python `datetime` object, and cleans and joins the text into a single string from a list of strings. \\

# %% [markdown]
# There two choices when it comes to deciding where to do the data processing:
# * `parse_items` in the spider
# * `process_items` in the pipeline

# %% [markdown]
# Multiple pipelines with different tasks can be declared in the *settings.py* file. However, Scrapy passes all items, regardless of item type, to each pipeline in order.

# %% [markdown]
# #Logging with Scrapy
# Adjust the level of logging by adding a line to the *settings.py* file:
#
#
# ```
# LOG_LEVEL = 'ERROR'
# ```
#
# The hierarchy of logging levels:
# * `CRITICAL`
# * `ERROR`
# * `WARNING`
# * `DEBUG`
# * `INFO`
#
# If logging is set to `ERROR`, only `CRITICAL` and `ERROR` logs will be displayed. If logging is
# set to `INFO`, all logs will be displayed, and so on.

# %% [markdown]
# #Resources
# Check the Scrapy documentation and other textbooks to learn more about Scrapy framework
